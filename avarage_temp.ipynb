# %%
import requests,json
from pylab import rcParams#出力画像のサイズ変更
from japanmap import *
# %matplotlib inline
import matplotlib.pyplot as plt
rcParams['figure.figsize']=10,10
#-------------------------------------------------------------------------------------
API_KEY = "0a5357d6b04726d418aad4cca2202999"
api = "http://api.openweathermap.org/data/2.5/weather?q={city}&units=metric&lang=ja&appid={key}"
count=0
data={}
color=[]
pref_list=['北海道', '青森県', '岩手県','宮城県', '秋田県', '山形県', '福島県', '茨城県', '栃木県',\
           '群馬県', '埼玉県', '千葉県', '東京都', '神奈川県', '新潟県', '富山県', '石川県', '福井県', \
           '山梨県', '長野県', '岐阜県', '静岡県', '愛知県', '三重県', '滋賀県', '京都府', '大阪府',\
           '兵庫県', '奈良県', '和歌山県', '鳥取県', '島根県', '岡山県', '広島県', '山口県', '徳島県', \
           '香川県', '愛媛県', '高知県', '福岡県', '佐賀県', '長崎県', '熊本県', '大分県', '宮崎県', \
           '鹿児島県', '沖縄県']
pref_weather=["Hokkaidō","Aomori-ken","Iwate-ken","Miyagi-ken","Akita-ken","Yamagata-ken","Fukushima-ken",\
              "Ibaraki-ken","Tochigi-ken","Gunma-ken","Saitama-ken","Chiba-ken","Tokyo","Kanagawa-ken",\
              "Niigata-ken","Toyama-ken","Ishikawa-ken","Fukui-ken","Yamanashi-ken","Nagano-ken","Gifu-ken",\
              "Shizuoka-ken","Aichi-ken","Mie-ken","Shiga-ken","Kyoto","Osaka-shi","Kobe-shi","Nara-ken",\
              "Wakayama-ken","Tottori","Shimane-ken","Okayama-ken","Hiroshima-ken","Yamaguchi-ken","Tokushima-ken",\
              "Kagawa-ken","Ehime-ken","Kochi-shi","Fukuoka-ken","Saga-ken","Nagasaki-ken","Kumamoto-ken",\
              "Oita-shi","Miyazaki-ken","Kagoshima-ken","Okinawa"]
#--------------------------------------------------------------------------------------
def temp_color(a):
    if a >= 34:
        color=(255,0,0)
        return color
    elif a>=30:
        color=(255,153,0)
        return color
    elif a>=26:
        color=(255,204,0)
        return color
    elif a>22:
        color=(255,255,0)
        return color
    elif a>18:
        color=(204,255,51)
        return color
    elif a>=14:
        color=(51,204,0)
        return color
    elif a>=10:
        color=(153,255,204)
        return color
    elif a>=6:
        color=(153,255,255)
        return color
    elif a>=2:
        color=(51,153,255)
        return color
    elif a>=-2:
        color=(0,0,255)
        return color
    elif a>=-6:
        color=(0,0,153)
        return color
    elif a>=-10:
        color=(0,0,51)
        return color
    else:
        color=(0,0,0)
        return color

for city_name in pref_weather:
    url = api.format(city = city_name, key = API_KEY)
    response = requests.get(url)
    data = json.loads(response.text)
    temp=data["main"]["temp"]
    color.append(temp)
for l,w in zip(pref_list,color):#dataに辞書形式で代入
    col=temp_color(w)
    data[l]=col
plt.title( u'avarage temperature' )
plt.imshow(picture(data));
